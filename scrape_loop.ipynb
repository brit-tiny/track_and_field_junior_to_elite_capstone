# %% [markdown]
# ### Scrape Loop

# %% [markdown]
#         "U20_W_high_jump": "https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/women/u20?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-30&lastDay=2025-10-18&maxResultsByCountry=all&eventId=10229526&ageCategory=u20",
#         "U20_W_long_jump": "https://worldathletics.org/records/all-time-toplists/jumps/long-jump/all/women/u20?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-30&lastDay=2025-10-18&maxResultsByCountry=all&eventId=10229528&ageCategory=u20",
#         "U20_W_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/women/u20?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-30&lastDay=2025-10-18&maxResultsByCountry=all&eventId=10229529&ageCategory=u20",
#         "Senior_W_high_jump": "https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/women/senior?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-30&lastDay=2025-10-18&maxResultsByCountry=all&eventId=10229526&ageCategory=senior",
#         "Senior_W_long_jump": "https://worldathletics.org/records/all-time-toplists/jumps/long-jump/all/women/senior?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-30&lastDay=2025-10-18&maxResultsByCountry=all&eventId=10229528&ageCategory=senior",
#         "Senior_W_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/women/senior?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-30&lastDay=2025-10-18&maxResultsByCountry=all&eventId=10229529&ageCategory=senior"

# %%
from world_athletics_scraper import scrape_all_pages

# %%
def main():
    events = {
        "U18_W_high_jump": "https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/women/u18?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-31&lastDay=2025-10-19&maxResultsByCountry=all&eventId=10229526&ageCategory=u18",
        "U18_W_long_jump": "https://worldathletics.org/records/all-time-toplists/jumps/long-jump/all/women/u18?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-30&lastDay=2025-10-18&maxResultsByCountry=all&eventId=10229528&ageCategory=u18",
        "U18_W_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/women/u18?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-30&lastDay=2025-10-18&maxResultsByCountry=all&eventId=10229529&ageCategory=u18",
        }

    for name, url in events.items():
        print(f"\nStarting Scrape for {name}")
        df = scrape_all_pages(url, max_pages=10, delay=1.0)
        print(f"Scraped {len(df)} rows.")
        df.to_csv(f"{name}.csv", index=False)
        print(f"Saved as {name}.csv")
    
    print("\n All request scraped and saved.")

if __name__ =="__main__":
    main()
# Out:
# Starting Scrape for U18_W_high_jump
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5
# Scraping page 6
# Scraping page 7
# Scraping page 8
# Scraping page 9
# Scraping page 10
# Scraped 1000 rows.
# Saved as U18_W_high_jump.csv
#
# Starting Scrape for U18_W_long_jump
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5
# Scraping page 6
# Scraping page 7
# Scraping page 8
# Scraping page 9
# Scraping page 10
# Scraped 320 rows.
# Saved as U18_W_long_jump.csv
#
# Starting Scrape for U18_W_triple_jump
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5
# Scraping page 6
# Scraping page 7
# Scraping page 8
# Scraping page 9
# Scraping page 10
# Scraped 220 rows.
# Saved as U18_W_triple_jump.csv
#
#  All request scraped and saved.

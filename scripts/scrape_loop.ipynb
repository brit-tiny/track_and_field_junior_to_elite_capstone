# %% [markdown]
# ### Scrape Loop

# %%
import os
from world_athletics_scraper import scrape_all_pages
from pathlib import Path
import random

# %%
# Save csv files to data/raw

PROJECT_ROOT = Path.cwd().parent
SAVE_DIR = PROJECT_ROOT / "data" / "raw"
SAVE_DIR.mkdir(parents=True, exist_ok=True)

print(f"Saving to: {SAVE_DIR}")
# Out:
# Saving to: c:\Users\Britt\Documents\Projects\capstone\data\raw

# %% [markdown]
# used to test if url = re.sub(r'([?&])page=\d+', f'\\1page={page}', base_url) line worked or was the cause of the error
# import re
# def scrape_all_pages(base_url):
#     for page in range(1,3):
#         url = re.sub(r'([?&])page=\d+', f'\\1page={page}', base_url)
#         print (url)
# scrape_all_pages("https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/women/senior?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-30&lastDay=2025-10-18&maxResultsByCountry=all&eventId=10229529&ageCategory=senior")

# %%
def main():
    events = {

        "u18_w_high_jump": "https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/women/u18?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229526&ageCategory=u18",
        "u18_w_long_jump": "https://worldathletics.org/records/all-time-toplists/jumps/long-jump/all/women/u18?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229528&ageCategory=u18",
        "u18_w_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/women/u18?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229529&ageCategory=u18",
        "u20_w_high_jump": "https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/women/u20?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229526&ageCategory=u20",
        "u20_w_long_jump": "https://worldathletics.org/records/all-time-toplists/jumps/long-jump/all/women/u20?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229528&ageCategory=u20",
        "u20_w_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/women/u20?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229529&ageCategory=u20",
        "senior_w_high_jump": "https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/women/senior?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229526&ageCategory=senior",
        "senior_w_long_jump": "https://worldathletics.org/records/all-time-toplists/jumps/long-jump/all/women/senior?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229528&ageCategory=senior",
        "senior_w_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/women/senior?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229529&ageCategory=senior"
    }    


    for name, url in events.items():
        print(f"\nStarting Scrape for {name}")
        df = scrape_all_pages(url, max_pages=75, delay=1.0)
        print(f"Scraped {len(df)} rows after dulicates removed.")

        #updated save path
        save_path = SAVE_DIR /f"{name}.csv"
        df.to_csv(save_path, index=False)
        print(f"Saved file to: {save_path}")
  
    print("\n All request pages scraped and saved.")

if __name__ == "__main__":
    main()
# Out:
# Starting Scrape for u18_w_high_jump
# Scraping page 1: https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/women/u18?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229526&ageCategory=u18
# Scraping page 2: https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/women/u18?regionType=world&page=2&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229526&ageCategory=u18
# Scraping page 3: https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/women/u18?regionType=world&page=3&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229526&ageCategory=u18
# ...

# %%
def main():
    events = {

        "u18_m_high_jump": "https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/men/u18?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229615&ageCategory=u18",
        "u18_m_long_jump": "https://worldathletics.org/records/all-time-toplists/jumps/long-jump/all/men/u18?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229617&ageCategory=u18",
        "u18_m_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/men/u18?regionType=world&windReading=regular&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229618&ageCategory=u18",
        "u20_m_high_jump": "https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/men/u20?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229615&ageCategory=u20",
        "u20_m_long_jump": "https://worldathletics.org/records/all-time-toplists/jumps/long-jump/all/men/u20?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229617&ageCategory=u20",
        "u20_m_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/men/u20?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229618&ageCategory=u20",
        "senior_m_high_jump": "https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/men/senior?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229615&ageCategory=senior",
        "senior_m_long_jump": "https://worldathletics.org/records/all-time-toplists/jumps/long-jump/all/men/senior?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229617&ageCategory=senior",
        "senior_m_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/men/senior?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229618&ageCategory=senior"
    }

    # Change max_pages page count to match the page count in the world_athletics_scraper.py 
    for name, url in events.items():
        print(f"\nStarting Scrape for {name}")
        df = scrape_all_pages(url, max_pages=135, delay=1.0)
        print(f"Scraped {len(df)} rows after dulicates removed.")

        #updated save path
        save_path = SAVE_DIR /f"{name}.csv"
        df.to_csv(save_path, index=False)
        print(f"Saved file to: {save_path}")
  
    print("\n All request pages scraped and saved.")

if __name__ == "__main__":
    main()
# Out:
# Starting Scrape for u18_m_high_jump
# Scraping page 1: https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/men/u18?regionType=world&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229615&ageCategory=u18
# Scraping page 2: https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/men/u18?regionType=world&page=2&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229615&ageCategory=u18
# No table found on https://worldathletics.org/records/all-time-toplists/jumps/high-jump/all/men/u18?regionType=world&page=2&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229615&ageCategory=u18
# No more results - stopping.
# Scraped 23 rows after dulicates removed.
# Saved file to: c:\Users\Britt\Documents\Projects\capstone\data\raw\u18_m_high_jump.csv
#
# Starting Scrape for u18_m_long_jump
# ...

# %%
def main():
    events = {

    "senior_m_triple_jump": "https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/men/senior?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229618&ageCategory=senior"
    }

    # Change max_pages page count to match the page count in the world_athletics_scraper.py 
    for name, url in events.items():
        print(f"\nStarting Scrape for {name}")
        df = scrape_all_pages(url, max_pages=135, delay=1.0)
        print(f"Scraped {len(df)} rows after dulicates removed.")

        #updated save path
        save_path = SAVE_DIR /f"{name}.csv"
        df.to_csv(save_path, index=False)
        print(f"Saved file to: {save_path}")
  
    print("\n All request pages scraped and saved.")

if __name__ == "__main__":
    main()
# Out:
# Starting Scrape for senior_m_triple_jump
# Scraping page 1: https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/men/senior?regionType=world&windReading=all&page=1&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229618&ageCategory=senior
# Scraping page 2: https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/men/senior?regionType=world&windReading=all&page=2&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229618&ageCategory=senior
# Scraping page 3: https://worldathletics.org/records/all-time-toplists/jumps/triple-jump/all/men/senior?regionType=world&windReading=all&page=3&bestResultsOnly=false&firstDay=1899-12-29&lastDay=2025-11-06&maxResultsByCountry=all&eventId=10229618&ageCategory=senior
# ...
